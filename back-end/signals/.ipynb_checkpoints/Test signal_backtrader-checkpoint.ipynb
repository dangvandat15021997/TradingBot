# %%
import sys
sys.path.append('../backtrader')
sys.path.append('../')
import config
from datafeed import  create_coin_price_dataFeed

import backtrader as bt

# %%
class EMA(bt.Strategy):
    params = dict(
        period = 200, 
        interval = '1d',
        minimumPeriod = 201
    )
    
    def __init__(self):
        self.p.minimumPeriod = self.p.period +1
        self.sma = bt.ind.EMA(self.data.close, period=self.p.period)  # fast moving average
        self.signal = bt.If(bt.And(self.datas[0].close > self.sma, self.datas[0].close > self.sma), 1, 0)

# %%
class EMA_200_signal():
    
    def __init__(self, name):
        self.name = name
#         self.indicators = [
#             { "id": "EMA",  
#             "interval" : self.interval,
#              "inputs" :
#              {
#                 "length" : 200,
#                 "source" : "close",
#                 "offset" : 0
#              } 
#             }
#         ]
        
        self.bt_strategy = EMA_200_SIGNAL
        self.result = None

        
    
    def signal(self, symbol):
        interval =  self.bt_strategy.params.interval
        print(interval)
        print(symbol)
        data_feed = create_coin_price_dataFeed(symbol, interval)
        # Create a data feed

        cerebro = bt.Cerebro() 
        cerebro.adddata(data_feed)  # Add the data feed
        cerebro.addstrategy(self.bt_strategy)  # Add the trading strategy
        self.result = cerebro.run()  # run it all
        
        
        if (self.result[0].signal[0] == 1):
            return True
        else :
            return False
        
    def backtest(self, symbol):
        interval =  self.bt_strategy.params.interval
        # Create a data feed
        data_feed = create_coin_price_dataFeed(symbol, interval)
        cerebro = bt.Cerebro() 
        cerebro.adddata(data_feed)  # Add the data feed
        cerebro.addstrategy(self.bt_strategy)  # Add the trading strategy
        self.result = cerebro.run()  # run it all

        cerebro.plot()

# %%
test = EMA_200_signal(name = 'EMA_200_1D')

# %%
test.signal('btcusdt')
# Out:
# 1d
# btcusdt
# True

# %%
test.backtest('btcusdt')
# Out:
# <img src="data:image/png;base64,..." width="863.1833333333333">

# %%
a

# %%
cerebro = bt.Cerebro() 
cerebro.adddata(a)  # Add the data feed
cerebro.addstrategy(EMA_200_SIGNAL)  # Add the trading strategy
# Out:
# 0

# %%
import EMA_200_signal
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-10-0120930d01f8> in <module>
# ----> 1 import EMA_200_signal
#
# ~\Desktop\TraddingBot\back-end\signals\EMA_200_signal.py in <module>
#       8 import numpy as np
#       9 import talib
# ---> 10 from EMA import EMA
#      11 import config
#      12 from datafeed import  create_coin_price_dataFeed
#
# ModuleNotFoundError: No module named 'EMA'

# %%
import sys
sys.path.append('../backtrader')
sys.path.append('../')
sys.path.append('./backtrader_signal')

# %%
import config
from datafeed import  create_coin_price_dataFeed

import backtrader as bt
from EMA import EMA

# %%
from EMA_200_signal import EMA_200_signal

# %%
test = EMA_200_signal(name = 'EMA_200_1D')

# %%
test.signal('btcusdt')
# Out:
# 1d
# btcusdt
# True
